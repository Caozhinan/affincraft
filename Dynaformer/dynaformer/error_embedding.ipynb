# %% [markdown]
# Embedding test

# %%
zncao02@f101$ p embedding_test.py /xcfhome/zncao02/affincraft/data/test.pkl
2025-07-14 15:33:41.001102: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
2025-07-14 15:33:42.725392: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
E0000 00:00:1752478423.257385 3179451 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
E0000 00:00:1752478423.505221 3179451 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
W0000 00:00:1752478424.526762 3179451 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752478424.526816 3179451 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752478424.526822 3179451 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752478424.526825 3179451 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
2025-07-14 15:33:44.748710: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
Traceback (most recent call last):
  File "/xcfhome/zncao02/affincraft/Dynaformer/dynaformer/embedding_test.py", line 18, in <module>
    from dynaformer.data.affincraft_dataset import (
  File "/xcfhome/zncao02/affincraft/Dynaformer/dynaformer/__init__.py", line 20, in <module>
    import dynaformer.criterions
  File "/xcfhome/zncao02/affincraft/Dynaformer/dynaformer/criterions/__init__.py", line 10, in <module>
    importlib.import_module("dynaformer.criterions." + file.name[:-3])
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/importlib/__init__.py", line 127, in import_module
    return _bootstrap._gcd_import(name[level:], package, level)
  File "/xcfhome/zncao02/affincraft/Dynaformer/dynaformer/criterions/binary_logloss.py", line 4, in <module>
    from fairseq.dataclass.configs import FairseqDataclass
  File "/xcfhome/zncao02/model_bap/Dynafomer/Dynaformer/fairseq/fairseq/__init__.py", line 21, in <module>
    from fairseq.logging import meters, metrics, progress_bar  # noqa
  File "/xcfhome/zncao02/model_bap/Dynafomer/Dynaformer/fairseq/fairseq/logging/progress_bar.py", line 387, in <module>
    import wandb
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/wandb/__init__.py", line 22, in <module>
    from wandb.sdk.lib import wb_logging as _wb_logging
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/wandb/sdk/__init__.py", line 25, in <module>
    from .artifacts.artifact import Artifact
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/wandb/sdk/artifacts/artifact.py", line 29, in <module>
    from wandb.apis.normalize import normalize_exceptions
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/wandb/apis/__init__.py", line 43, in <module>
    from .internal import Api as InternalApi  # noqa
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/wandb/apis/internal.py", line 3, in <module>
    from wandb.sdk.internal.internal_api import Api as InternalApi
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/wandb/sdk/internal/internal_api.py", line 49, in <module>
    from wandb.sdk.internal._generated import SERVER_FEATURES_QUERY_GQL, ServerFeaturesQuery
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/wandb/sdk/internal/_generated/__init__.py", line 4, in <module>
    from .server_features_query import (
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/wandb/sdk/internal/_generated/server_features_query.py", line 10, in <module>
    from wandb._pydantic import GQLBase
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/wandb/_pydantic/__init__.py", line 3, in <module>
    from .base import Base, GQLBase, GQLId, SerializedToJson, Typename
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/wandb/_pydantic/base.py", line 10, in <module>
    from .v1_compat import PydanticCompatMixin
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/wandb/_pydantic/v1_compat.py", line 178, in <module>
    field_validator = pydantic.field_validator
AttributeError: module 'pydantic' has no attribute 'field_validator'

# %%
Collecting pathtools (from wandb==0.15.12)
  Downloading http://mirrors.aliyun.com/pypi/packages/e7/7f/470d6fcdf23f9f3518f6b0b76be9df16dcc8630ad409947f8be2eb0ed13a/pathtools-0.1.2.tar.gz (11 kB)
  Preparing metadata (setup.py) ... done
Requirement already satisfied: setproctitle in /xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages (from wandb==0.15.12) (1.3.5)
Requirement already satisfied: setuptools in /xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages (from wandb==0.15.12) (59.5.0)
Collecting appdirs>=1.4.3 (from wandb==0.15.12)
  Downloading http://mirrors.aliyun.com/pypi/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
Requirement already satisfied: typing-extensions in /xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages (from wandb==0.15.12) (4.12.2)
Collecting protobuf!=4.21.0,<5,>=3.15.0 (from wandb==0.15.12)
  Downloading http://mirrors.aliyun.com/pypi/packages/d6/c6/c9deaa6e789b6fc41b88ccbdfe7a42d2b82663248b715f55aa77fbc00724/protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
Requirement already satisfied: charset-normalizer<4,>=2 in /xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages (from requests<3,>=2.0.0->wandb==0.15.12) (3.4.1)
Requirement already satisfied: idna<4,>=2.5 in /xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages (from requests<3,>=2.0.0->wandb==0.15.12) (3.10)
Requirement already satisfied: urllib3<3,>=1.21.1 in /xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages (from requests<3,>=2.0.0->wandb==0.15.12) (2.4.0)
Requirement already satisfied: certifi>=2017.4.17 in /xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages (from requests<3,>=2.0.0->wandb==0.15.12) (2025.1.31)
Requirement already satisfied: six>=1.4.0 in /xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages (from docker-pycreds>=0.4.0->wandb==0.15.12) (1.17.0)
Requirement already satisfied: gitdb<5,>=4.0.1 in /xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.15.12) (4.0.12)
Requirement already satisfied: smmap<6,>=3.0.1 in /xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.15.12) (5.0.2)
Building wheels for collected packages: pathtools
  DEPRECATION: Building 'pathtools' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pathtools'. Discussion can be found at https://github.com/pypa/pip/issues/6334
  Building wheel for pathtools (setup.py) ... done
  Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8883 sha256=6407364d8c0030a10198fe0eb21474e73f571ff7c13e7fac3ce7b4622165125f
  Stored in directory: /xcfhome/zncao02/.cache/pip/wheels/99/37/da/ee67272eb340bcdedaab1cddd159b514d1c02609f2841d4b17
Successfully built pathtools
WARNING: Error parsing dependencies of omegaconf: .* suffix can only be used with `==` or `!=` operators
    PyYAML (>=5.1.*)
            ~~~~~~^
Installing collected packages: pathtools, appdirs, protobuf, wandb
  Attempting uninstall: protobuf
    Found existing installation: protobuf 5.29.5
    Uninstalling protobuf-5.29.5:
      Successfully uninstalled protobuf-5.29.5
  Attempting uninstall: wandb
    Found existing installation: wandb 0.19.9
    Uninstalling wandb-0.19.9:
      Successfully uninstalled wandb-0.19.9
ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 1.20.3 which is incompatible.

# %%
(dynaformer) ~/affincraft/Dynaformer/dynaformer
zncao02@f101$ p embedding_test.py /xcfhome/zncao02/affincraft/data/test.pkl
2025-07-14 15:57:23.682964: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
2025-07-14 15:57:23.701383: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
E0000 00:00:1752479843.722507 3266712 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
E0000 00:00:1752479843.729467 3266712 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
W0000 00:00:1752479843.746298 3266712 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752479843.746333 3266712 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752479843.746336 3266712 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752479843.746339 3266712 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
2025-07-14 15:57:23.751703: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/wandb/sdk/launch/builder/build.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
  import pkg_resources
Traceback (most recent call last):
  File "/xcfhome/zncao02/affincraft/Dynaformer/dynaformer/embedding_test.py", line 18, in <module>
    from dynaformer.data.affincraft_dataset import (
  File "/xcfhome/zncao02/affincraft/Dynaformer/dynaformer/__init__.py", line 20, in <module>
    import dynaformer.criterions
  File "/xcfhome/zncao02/affincraft/Dynaformer/dynaformer/criterions/__init__.py", line 10, in <module>
    importlib.import_module("dynaformer.criterions." + file.name[:-3])
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/importlib/__init__.py", line 127, in import_module
    return _bootstrap._gcd_import(name[level:], package, level)
  File "/xcfhome/zncao02/affincraft/Dynaformer/dynaformer/criterions/binary_logloss.py", line 4, in <module>
    from fairseq.dataclass.configs import FairseqDataclass
  File "/xcfhome/zncao02/model_bap/Dynafomer/Dynaformer/fairseq/fairseq/__init__.py", line 33, in <module>
    import fairseq.criterions  # noqa
  File "/xcfhome/zncao02/model_bap/Dynafomer/Dynaformer/fairseq/fairseq/criterions/__init__.py", line 36, in <module>
    importlib.import_module("fairseq.criterions." + file_name)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/importlib/__init__.py", line 127, in import_module
    return _bootstrap._gcd_import(name[level:], package, level)
  File "/xcfhome/zncao02/model_bap/Dynafomer/Dynaformer/fairseq/fairseq/criterions/ctc.py", line 19, in <module>
    from fairseq.tasks import FairseqTask
  File "/xcfhome/zncao02/model_bap/Dynafomer/Dynaformer/fairseq/fairseq/tasks/__init__.py", line 136, in <module>
    import_tasks(tasks_dir, "fairseq.tasks")
  File "/xcfhome/zncao02/model_bap/Dynafomer/Dynaformer/fairseq/fairseq/tasks/__init__.py", line 117, in import_tasks
    importlib.import_module(namespace + "." + task_name)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/importlib/__init__.py", line 127, in import_module
    return _bootstrap._gcd_import(name[level:], package, level)
  File "/xcfhome/zncao02/model_bap/Dynafomer/Dynaformer/fairseq/fairseq/tasks/frm_text_to_speech.py", line 10, in <module>
    from fairseq.tasks.text_to_speech import TextToSpeechTask
  File "/xcfhome/zncao02/model_bap/Dynafomer/Dynaformer/fairseq/fairseq/tasks/text_to_speech.py", line 32, in <module>
    from tensorboardX import SummaryWriter
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorboardX/__init__.py", line 5, in <module>
    from .torchvis import TorchVis
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorboardX/torchvis.py", line 11, in <module>
    from .writer import SummaryWriter
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorboardX/writer.py", line 17, in <module>
    from .comet_utils import CometLogger
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorboardX/comet_utils.py", line 6, in <module>
    from .summary import _clean_tag
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorboardX/summary.py", line 13, in <module>
    from .proto.summary_pb2 import Summary
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorboardX/proto/summary_pb2.py", line 16, in <module>
    from tensorboardX.proto import tensor_pb2 as tensorboardX_dot_proto_dot_tensor__pb2
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorboardX/proto/tensor_pb2.py", line 21, in <module>
    DESCRIPTOR = _descriptor.FileDescriptor(
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/google/protobuf/descriptor.py", line 1072, in __new__
    return _message.default_pool.AddSerializedFile(serialized_pb)
TypeError: Couldn't build proto file into descriptor pool: Depends on file 'tensorboardX/proto/resource_handle.proto', but it has not been loaded

# %%
zncao02@f101$ python embedding_test.py /xcfhome/zncao02/affincraft/data/test.pkl
2025-07-14 16:04:03.076183: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
2025-07-14 16:04:03.095356: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
E0000 00:00:1752480243.117081 3287501 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
E0000 00:00:1752480243.124145 3287501 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
W0000 00:00:1752480243.141845 3287501 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752480243.141873 3287501 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752480243.141878 3287501 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752480243.141881 3287501 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
2025-07-14 16:04:03.147322: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/wandb/sdk/launch/builder/build.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
  import pkg_resources
2025-07-14 16:04:09 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
Loading PKL file: /xcfhome/zncao02/affincraft/data/test.pkl
Loaded 1 complexes
Created 1 temporary PKL files
Created dataset with 1 items
Testing embedding pipeline...
Cleaned up temporary files
Traceback (most recent call last):
  File "/xcfhome/zncao02/affincraft/Dynaformer/dynaformer/embedding_test.py", line 159, in <module>
    main()
  File "/xcfhome/zncao02/affincraft/Dynaformer/dynaformer/embedding_test.py", line 156, in main
    test_embedding_pipeline(args.pkl_file, args.batch_size, args.max_complexes)
  File "/xcfhome/zncao02/affincraft/Dynaformer/dynaformer/embedding_test.py", line 94, in test_embedding_pipeline
    for batch_idx, batch_data in enumerate(dataloader):
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 708, in __next__
    data = self._next_data()
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 764, in _next_data
    data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py", line 52, in fetch
    data = [self.dataset[idx] for idx in possibly_batched_index]
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py", line 52, in <listcomp>
    data = [self.dataset[idx] for idx in possibly_batched_index]
  File "/xcfhome/zncao02/affincraft/Dynaformer/dynaformer/data/affincraft_dataset.py", line 24, in __getitem__
    return preprocess_affincraft_item(pkl_data)
  File "/xcfhome/zncao02/affincraft/Dynaformer/dynaformer/data/affincraft_dataset.py", line 48, in preprocess_affincraft_item
    'input_feat': torch.from_numpy(pkl_data['masif_input_feat']),
KeyError: 'masif_input_feat'

# %%
zncao02@f101$ p embedding_test.py /xcfhome/zncao02/affincraft/data/6w1i-G4P/output/6w1i-G4P_features_with_masif.pkl
2025-07-14 18:38:31.834697: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
2025-07-14 18:38:32.231637: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
E0000 00:00:1752489512.373401 3958962 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
E0000 00:00:1752489512.426745 3958962 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
W0000 00:00:1752489512.730729 3958962 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752489512.730775 3958962 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752489512.730778 3958962 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752489512.730782 3958962 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
2025-07-14 18:38:32.781310: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/wandb/sdk/launch/builder/build.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
  import pkg_resources
2025-07-14 18:38:48 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
Loading PKL file: /xcfhome/zncao02/affincraft/data/6w1i-G4P/output/6w1i-G4P_features_with_masif.pkl
Loaded 1 complexes
Created 1 temporary PKL files
Created dataset with 1 items
Testing embedding pipeline...

Batch 0:
  Batch size: 1
  Node features shape: torch.Size([1, 170, 9])
  Edge features: 1 items
  GB-Score shape: torch.Size([1, 400])
  MaSIF desc shape: torch.Size([1, 3888, 80])
  ✗ Embedding failed: 'list' object has no attribute 'size'
Traceback (most recent call last):
  File "/xcfhome/zncao02/affincraft/Dynaformer/dynaformer/embedding_test.py", line 108, in test_embedding_pipeline
    inner_states, graph_rep = encoder(batch_data)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
    return self._call_impl(*args, **kwargs)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1750, in _call_impl
    return forward_call(*args, **kwargs)
  File "/xcfhome/zncao02/affincraft/Dynaformer/dynaformer/modules/affincraft_graph_encoder.py", line 176, in forward
    attn_bias = self.graph_attn_bias(batched_data)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1739, in _wrapped_call_impl
    return self._call_impl(*args, **kwargs)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1750, in _call_impl
    return forward_call(*args, **kwargs)
  File "/xcfhome/zncao02/affincraft/Dynaformer/dynaformer/modules/graphormer_layers.py", line 158, in forward
    n_graph, n_edge, _ = edge_feat.size()
AttributeError: 'list' object has no attribute 'size'

Test completed! Processed 0 complexes successfully.

Testing individual complex processing...
Sample complex: 6w1i-G4P
Node features: torch.Size([170, 9])
Edge features: torch.Size([2266, 4])
Cleaned up temporary files

# %%
To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/wandb/sdk/launch/builder/build.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
  import pkg_resources
2025-07-14 19:23:39 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
Loading PKL file: /xcfhome/zncao02/affincraft/data/6w1i-G4P/output/6w1i-G4P_features_with_masif.pkl
Loaded 1 complexes
Created 1 temporary PKL files
Created dataset with 1 items
Testing embedding pipeline...

Batch 0:
  Batch size: 1
  Node features shape: torch.Size([1, 170, 9])
  Edge features: 1 items
  GB-Score shape: torch.Size([1, 400])
  MaSIF desc shape: torch.Size([1, 3888, 80])
  ✓ Embedding successful!
  Graph representation shape: torch.Size([1, 256])
  Number of transformer states: 7
  Final state shape: torch.Size([171, 1, 256])
  Graph rep mean: nan
  Graph rep std: nan
  Graph rep range: [nan, nan]
Input node features contain NaN: False
Input edge features contain NaN: False
Input GB-Score contain NaN: False
Input MaSIF contain NaN: True

Test completed! Processed 1 complexes successfully.

Testing individual complex processing...
Sample complex: 6w1i-G4P
Node features: torch.Size([170, 9])
Edge features: torch.Size([2266, 4])
Cleaned up temporary files

# %%
enerated PKL file: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/2aco-VCA_features.pkl
Step 2: Running meshfeatureGen.py...
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/prody/utilities/misctools.py:411: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
  import pkg_resources
开始蛋白质-配体表面特征计算...
质子化PDB文件...
提取链 A...
计算MSMS分子表面...
处理配体 UNK...
DEBUG: Reading ligand from SDF file: /xcfhome/zncao02/affincraft/data/2aco-VCA/ligand.sdf
Added @<TRIPOS>SUBSTRUCTURE section to /xcfhome/zncao02/affincraft/data/2aco-VCA/output/tmp/UNK_X.mol2
Error during SDF to MOL2 conversion: not enough values to unpack (expected 4, got 0)
MOL2 文件生成失败
计算化学特征...
  - 计算氢键特征...
  - 计算疏水性特征...
修复和正则化网格...
Removing degenerated triangles
网格修复完成!
计算几何特征...
计算APBS静电特征...
### PDB2PQR ###
 
### APBS ###
 Vio_ctor2: some error occurred.
Vio_ctor: Vio_ctor2() failed.
Error while opening input file complex_A.in!

### MULTIVALUE ###
 Vio_ctor2: some error occurred.
Vio_ctor: Vio_ctor2() failed.
Vgrid_readDX: Problem opening virtual socket complex_A.dx
main:  Problem reading standard OpenDX-format grid from complex_A.dx

Traceback (most recent call last):
  File "/xcfhome/zncao02/affincraft/masif/meshfeatureGen.py", line 263, in <module>
    result = compute_protein_ligand_surface_features(
  File "/xcfhome/zncao02/affincraft/masif/meshfeatureGen.py", line 142, in compute_protein_ligand_surface_features
    vertex_charges = computeAPBS(
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/computeAPBS.py", line 64, in computeAPBS
    chargefile = open(tmp_file_base + "_out.csv")
FileNotFoundError: [Errno 2] No such file or directory: '/xcfhome/zncao02/affincraft/data/2aco-VCA/output/tmp//complex_A_out.csv'
Error in meshfeatureGen.py for 2aco-VCA
All processing completed!

# %%
ncao02@f101$ bash preprocess.sh ./data/2aco.csv 
Processing: 2aco-VCA
Target directory: /xcfhome/zncao02/affincraft/data/2aco-VCA
Output directory: /xcfhome/zncao02/affincraft/data/2aco-VCA/output
Step 1: Running custom_input.py...
100%|████████████████████████████████████████████████████| 1/1 [00:00<00:00, 72.23it/s]
Warning: use "from pymol import cmd" instead of "import cmd"
正在进行PLIP分析: 2aco-VCA
PLIP分析结果类型: <class 'dict'>
发现的结合位点数: 1
lig_ea shape: (38, 4)
pro_ea shape: (176, 4)
lig_sea shape: (102, 4)
pro_sea shape: (886, 4)
lig_pock_ea shape: (22, 4)
Generated PKL file: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/2aco-VCA_features.pkl
Step 2: Running meshfeatureGen.py...
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/prody/utilities/misctools.py:411: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
  import pkg_resources
开始蛋白质-配体表面特征计算...
质子化PDB文件...
提取链 A...
计算MSMS分子表面...
处理配体 UNK...
DEBUG: Reading ligand from SDF file: /xcfhome/zncao02/affincraft/data/2aco-VCA/ligand.sdf
Added @<TRIPOS>SUBSTRUCTURE section to /xcfhome/zncao02/affincraft/data/2aco-VCA/output/tmp/UNK_X.mol2
DEBUG: Using modified amide_to_single_bond function
成功生成 MOL2 文件: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/tmp/UNK_X.mol2
计算化学特征...
  - 计算氢键特征...
  - 计算疏水性特征...
修复和正则化网格...
Removing degenerated triangles
网格修复完成!
计算几何特征...
计算APBS静电特征...
### PDB2PQR ###
 
### APBS ###
 Vio_ctor2: some error occurred.
Vio_ctor: Vio_ctor2() failed.
Error while opening input file complex_A.in!

### MULTIVALUE ###
 Vio_ctor2: some error occurred.
Vio_ctor: Vio_ctor2() failed.
Vgrid_readDX: Problem opening virtual socket complex_A.dx
main:  Problem reading standard OpenDX-format grid from complex_A.dx

Traceback (most recent call last):
  File "/xcfhome/zncao02/affincraft/masif/meshfeatureGen.py", line 263, in <module>
    result = compute_protein_ligand_surface_features(
  File "/xcfhome/zncao02/affincraft/masif/meshfeatureGen.py", line 142, in compute_protein_ligand_surface_features
    vertex_charges = computeAPBS(
  File "/xcfhome/zncao02/affincraft/masif/source/triangulation/computeAPBS.py", line 64, in computeAPBS
    chargefile = open(tmp_file_base + "_out.csv")
FileNotFoundError: [Errno 2] No such file or directory: '/xcfhome/zncao02/affincraft/data/2aco-VCA/output/tmp//complex_A_out.csv'
Error in meshfeatureGen.py for 2aco-VCA
All processing completed!

# %% [markdown]
# #
# log

# %%
zncao02@f101$ bash preprocess.sh ./data/2aco.csv 
Processing: 2aco-VCA
Target directory: /xcfhome/zncao02/affincraft/data/2aco-VCA
Output directory: /xcfhome/zncao02/affincraft/data/2aco-VCA/output
Step 1: Running custom_input.py...
100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 73.59it/s]
Warning: use "from pymol import cmd" instead of "import cmd"
正在进行PLIP分析: 2aco-VCA
PLIP分析结果类型: <class 'dict'>
发现的结合位点数: 1
lig_ea shape: (38, 4)
pro_ea shape: (176, 4)
lig_sea shape: (102, 4)
pro_sea shape: (886, 4)
lig_pock_ea shape: (22, 4)
Generated PKL file: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/2aco-VCA_features.pkl
Step 2: Running meshfeatureGen.py...
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/prody/utilities/misctools.py:411: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
  import pkg_resources
开始蛋白质-配体表面特征计算...
质子化PDB文件...
提取链 A...
计算MSMS分子表面...
处理配体 UNK...
DEBUG: Reading ligand from SDF file: /xcfhome/zncao02/affincraft/data/2aco-VCA/ligand.sdf
DEBUG: Using modified amide_to_single_bond function
[OK] Atom names fixed in /xcfhome/zncao02/affincraft/data/2aco-VCA/output/tmp/UNK_X.mol2
[OK] SDF to MOL2 conversion and cleaning done: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/tmp/UNK_X.mol2
成功生成 MOL2 文件: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/tmp/UNK_X.mol2
计算化学特征...
  - 计算氢键特征...
  - 计算疏水性特征...
修复和正则化网格...
Removing degenerated triangles
网格修复完成!
计算几何特征...
计算APBS静电特征...
### PDB2PQR ###
 Warning: multiple occupancies found: O1 in LIG L 1
Warning: multiple occupancies found: C1 in LIG L 1
Warning: multiple occupancies found: O2 in LIG L 1
Warning: multiple occupancies found: C2 in LIG L 1
Warning: multiple occupancies found: C3 in LIG L 1
Warning: multiple occupancies found: C4 in LIG L 1
Warning: multiple occupancies found: C5 in LIG L 1
Warning: multiple occupancies found: C6 in LIG L 1
Warning: multiple occupancies found: C7 in LIG L 1
Warning: multiple occupancies found: C8 in LIG L 1
Warning: multiple occupancies found: C9 in LIG L 1
Warning: multiple occupancies found: C10 in LIG L 1
Warning: multiple occupancies found: C11 in LIG L 1
Warning: multiple occupancies found: C12 in LIG L 1
Warning: multiple occupancies found: C13 in LIG L 1
Warning: multiple occupancies found: C14 in LIG L 1
Warning: multiple occupancies found: C15 in LIG L 1
Warning: multiple occupancies found: C16 in LIG L 1
Warning: multiple occupancies found: C17 in LIG L 1
Warning: multiple occupancies found: C18 in LIG L 1
Warning: multiple occupancies found: H1 in LIG L 1
Warning: multiple occupancies found: H2 in LIG L 1
Warning: multiple occupancies found: H3 in LIG L 1
Warning: multiple occupancies found: H4 in LIG L 1
Warning: multiple occupancies found: H5 in LIG L 1
Warning: multiple occupancies found: H6 in LIG L 1
Warning: multiple occupancies found: H7 in LIG L 1
Warning: multiple occupancies found: H8 in LIG L 1
Warning: multiple occupancies found: H9 in LIG L 1
Warning: multiple occupancies found: H10 in LIG L 1
Warning: multiple occupancies found: H11 in LIG L 1
Warning: multiple occupancies found: H12 in LIG L 1
Warning: multiple occupancies found: H13 in LIG L 1
Warning: multiple occupancies found: H14 in LIG L 1
Warning: multiple occupancies found: H15 in LIG L 1
Warning: multiple occupancies found: H16 in LIG L 1
Warning: multiple occupancies found: H17 in LIG L 1
Warning: multiple occupancies found: H18 in LIG L 1
Warning: multiple occupancies found: H19 in LIG L 1
Warning: multiple occupancies found: H20 in LIG L 1
Warning: multiple occupancies found: H21 in LIG L 1
Warning: multiple occupancies found: H22 in LIG L 1
Warning: multiple occupancies found: H23 in LIG L 1
Warning: multiple occupancies found: H24 in LIG L 1
Warning: multiple occupancies found: H25 in LIG L 1
Warning: multiple occupancies found: H26 in LIG L 1
Warning: multiple occupancies found: H27 in LIG L 1
Warning: multiple occupancies found: H28 in LIG L 1
Warning: multiple occupancies found: H29 in LIG L 1
Warning: multiple occupancies found: H30 in LIG L 1
Warning: multiple occupancies found: H31 in LIG L 1
Warning: multiple occupancies found: H32 in LIG L 1
Warning: multiple occupancies found: H33 in LIG L 1

### APBS ###
 
### MULTIVALUE ###
 
APBS计算完成!
计算界面特征...
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom O defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 53.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 54.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 55.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 56.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 57.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 58.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 59.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 60.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 61.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 62.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 63.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 64.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 65.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 66.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 67.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 68.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 69.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 70.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'TER' at line 2713
  warnings.warn(
计算曲率和形状特征...
构建增强特征字典...
表面特征计算完成!
顶点数: 22
面数: 40
特征维度: 11
Step 3: Running feature_precompute.py...
开始Step 3: 特征预计算...
处理PLY文件: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/surfaces/complex_A.ply
输出目录: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/precomputed/complex_A/
读取表面数据并计算patch特征...
Dijkstra took 0.00s
Only MDS time: 1.85s
Full loop time: 1.97s
MDS took 1.97s
成功计算特征:
  - 顶点数: 22
  - 输入特征维度: (22, 100, 5)
  - 极坐标 rho: (22, 100)
  - 极坐标 theta: (22, 100)
  - 邻居索引: 22
保存预计算特征...
特征保存完成!
Step 3完成! 生成了 22 个patches，每个patch有 5 维特征
Step 4: Running fingerprint_gen.py...
2025-07-15 15:13:43.243353: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
2025-07-15 15:13:46.015636: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
E0000 00:00:1752563626.408700 4078128 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
E0000 00:00:1752563626.590385 4078128 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
W0000 00:00:1752563627.710367 4078128 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752563627.710410 4078128 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752563627.710416 4078128 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752563627.710420 4078128 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
2025-07-15 15:13:47.851935: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
WARNING:tensorflow:From /xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
Instructions for updating:
non-resource variables are not supported in the long term
开始Step 4: 基于神经网络的指纹生成...
从目录加载预计算特征: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/precomputed/complex_A
警告: 无法加载自定义参数文件 masif.source.masif_ppi_search.nn_models.sc05.all_feat.custom_params: No module named 'masif.source.masif_ppi_search.nn_models'
将使用默认参数。
加载预训练的神经网络模型...
(80, 2)
I0000 00:00:1752563807.664426 4078128 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 16226 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:3b:00.0, compute capability: 8.6
I0000 00:00:1752563807.675626 4078128 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22314 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:d8:00.0, compute capability: 8.6
WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
I0000 00:00:1752563808.145566 4078128 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
<tf.Variable 'mu_rho_0:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_theta_0:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_rho_0:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_theta_0:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_rho_1:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_theta_1:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_rho_1:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_theta_1:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_rho_2:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_theta_2:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_rho_2:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_theta_2:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_rho_3:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_theta_3:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_rho_3:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_theta_3:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_rho_4:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_theta_4:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_rho_4:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_theta_4:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'b_conv_0:0' shape=(80,) dtype=float32_ref>
80
<tf.Variable 'b_conv_1:0' shape=(80,) dtype=float32_ref>
80
<tf.Variable 'b_conv_2:0' shape=(80,) dtype=float32_ref>
80
<tf.Variable 'b_conv_3:0' shape=(80,) dtype=float32_ref>
80
<tf.Variable 'b_conv_4:0' shape=(80,) dtype=float32_ref>
80
<tf.Variable 'W_conv_0:0' shape=(80, 80) dtype=float32_ref>
6400
<tf.Variable 'W_conv_1:0' shape=(80, 80) dtype=float32_ref>
6400
<tf.Variable 'W_conv_2:0' shape=(80, 80) dtype=float32_ref>
6400
<tf.Variable 'W_conv_3:0' shape=(80, 80) dtype=float32_ref>
6400
<tf.Variable 'W_conv_4:0' shape=(80, 80) dtype=float32_ref>
6400
<tf.Variable 'fully_connected/weights:0' shape=(400, 80) dtype=float32_ref>
32000
<tf.Variable 'fully_connected/biases:0' shape=(80,) dtype=float32_ref>
80
Total number parameters: 66080
使用绝对路径加载模型: /xcfhome/zncao02/AffinSculptor/masif/data/masif_ppi_search/nn_models/sc05/all_feat/model_data/
神经网络模型加载成功。
预计算特征数据加载成功。
计算表面描述符 (指纹)...
描述符计算完成，耗时: 14.05s
表面指纹已保存到: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/descriptors/complex_A
Step 4完成! 生成了 22 个指纹，每个指纹维度为 80。
\n=== Step 4 输出指纹总结 ===
标准方向指纹形状: (22, 80)
翻转方向指纹形状: (22, 80)
指纹文件保存在: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/descriptors/complex_A
Step 5: Merging MaSIF features to existing PKL...
加载现有PKL文件: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/2aco-VCA_features.pkl
现有PKL文件包含 1 个复合物
加载MaSIF特征...
  加载 masif_input_feat: (22, 100, 5)
  加载 masif_rho_wrt_center: (22, 100)
  加载 masif_theta_wrt_center: (22, 100)
  加载 masif_mask: (22, 100)
  加载 masif_desc_straight: (22, 80)
  加载 masif_desc_flipped: (22, 80)
找到目标复合物: 2aco-VCA
保存整合后的PKL文件到: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/2aco-VCA_features_with_masif.pkl
整合完成!
MaSIF特征总结:
  - masif_input_feat: (22, 100, 5)
  - masif_rho_wrt_center: (22, 100)
  - masif_theta_wrt_center: (22, 100)
  - masif_mask: (22, 100)
  - masif_desc_straight: (22, 80)
  - masif_desc_flipped: (22, 80)
整合成功!
Completed processing for 2aco-VCA
----------------------------------------
All processing completed!

# %%
DEBUG: Reading ligand from SDF file: /xcfhome/zncao02/affincraft/data/2aco-VCA/ligand.sdf
DEBUG: Using modified amide_to_single_bond function
[OK] Atom names fixed in /xcfhome/zncao02/affincraft/data/2aco-VCA/output/tmp/UNK_X.mol2
[OK] SDF to MOL2 conversion and cleaning done: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/tmp/UNK_X.mol2
成功生成 MOL2 文件: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/tmp/UNK_X.mol2
计算化学特征...
  - 计算氢键特征...
  - 计算疏水性特征...
修复和正则化网格...
Removing degenerated triangles
网格修复完成!
计算几何特征...
计算APBS静电特征...
### PDB2PQR ###
 
### APBS ###
 
### MULTIVALUE ###
 
APBS计算完成!
计算界面特征...
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom O defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 53.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 54.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 55.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 56.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 57.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 58.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 59.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 60.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 61.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 62.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 63.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 64.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 65.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 66.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 67.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 68.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 69.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:416: PDBConstructionWarning: PDBConstructionException: Atom C defined twice in residue <Residue UNK het=H_UNK resseq=0 icode= > at line 70.
Exception ignored.
Some atoms or residues may be missing in the data structure.
  warnings.warn(
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'TER' at line 2713
  warnings.warn(
计算曲率和形状特征...
构建增强特征字典...
表面特征计算完成!
顶点数: 3535
面数: 7070
特征维度: 11
Step 3: Running feature_precompute.py...
开始Step 3: 特征预计算...
处理PLY文件: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/surfaces/complex_B.ply
输出目录: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/precomputed/complex_B/
读取表面数据并计算patch特征...
Dijkstra took 2.68s
Only MDS time: 26.77s
Full loop time: 32.45s
MDS took 32.45s
成功计算特征:
  - 顶点数: 3535
  - 输入特征维度: (3535, 100, 5)
  - 极坐标 rho: (3535, 100)
  - 极坐标 theta: (3535, 100)
  - 邻居索引: 3535
保存预计算特征...
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
  return array(a, dtype, copy=False, order=order, subok=True)
特征保存完成!
Step 3完成! 生成了 3535 个patches，每个patch有 5 维特征
Step 4: Running fingerprint_gen.py...
2025-07-15 16:45:49.968015: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
2025-07-15 16:45:49.985094: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
E0000 00:00:1752569150.003672 1170371 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
E0000 00:00:1752569150.009402 1170371 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
W0000 00:00:1752569150.024636 1170371 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752569150.024660 1170371 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752569150.024663 1170371 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752569150.024665 1170371 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
2025-07-15 16:45:50.029588: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
WARNING:tensorflow:From /xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
Instructions for updating:
non-resource variables are not supported in the long term
开始Step 4: 基于神经网络的指纹生成...
从目录加载预计算特征: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/precomputed/complex_B
警告: 无法加载自定义参数文件 masif.source.masif_ppi_search.nn_models.sc05.all_feat.custom_params: No module named 'masif.source.masif_ppi_search.nn_models'
将使用默认参数。
加载预训练的神经网络模型...
(80, 2)
I0000 00:00:1752569166.099008 1170371 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3474 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:3b:00.0, compute capability: 8.6
I0000 00:00:1752569166.100616 1170371 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 3470 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:d8:00.0, compute capability: 8.6
WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
I0000 00:00:1752569166.451659 1170371 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
<tf.Variable 'mu_rho_0:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_theta_0:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_rho_0:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_theta_0:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_rho_1:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_theta_1:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_rho_1:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_theta_1:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_rho_2:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_theta_2:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_rho_2:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_theta_2:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_rho_3:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_theta_3:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_rho_3:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_theta_3:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_rho_4:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_theta_4:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_rho_4:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_theta_4:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'b_conv_0:0' shape=(80,) dtype=float32_ref>
80
<tf.Variable 'b_conv_1:0' shape=(80,) dtype=float32_ref>
80
<tf.Variable 'b_conv_2:0' shape=(80,) dtype=float32_ref>
80
<tf.Variable 'b_conv_3:0' shape=(80,) dtype=float32_ref>
80
<tf.Variable 'b_conv_4:0' shape=(80,) dtype=float32_ref>
80
<tf.Variable 'W_conv_0:0' shape=(80, 80) dtype=float32_ref>
6400
<tf.Variable 'W_conv_1:0' shape=(80, 80) dtype=float32_ref>
6400
<tf.Variable 'W_conv_2:0' shape=(80, 80) dtype=float32_ref>
6400
<tf.Variable 'W_conv_3:0' shape=(80, 80) dtype=float32_ref>
6400
<tf.Variable 'W_conv_4:0' shape=(80, 80) dtype=float32_ref>
6400
<tf.Variable 'fully_connected/weights:0' shape=(400, 80) dtype=float32_ref>
32000
<tf.Variable 'fully_connected/biases:0' shape=(80,) dtype=float32_ref>
80
Total number parameters: 66080
使用绝对路径加载模型: /xcfhome/zncao02/affincraft/masif/data/masif_ppi_search/nn_models/sc05/all_feat/model_data/
神经网络模型加载成功。
预计算特征数据加载成功。
计算表面描述符 (指纹)...
描述符计算完成，耗时: 9.10s
表面指纹已保存到: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/descriptors/complex_B
Step 4完成! 生成了 3535 个指纹，每个指纹维度为 80。
\n=== Step 4 输出指纹总结 ===
标准方向指纹形状: (3535, 80)
翻转方向指纹形状: (3535, 80)
指纹文件保存在: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/descriptors/complex_B
Step 5: Merging MaSIF features to existing PKL...
加载现有PKL文件: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/2aco-VCA_features.pkl
现有PKL文件包含 1 个复合物
加载MaSIF特征...
  加载 masif_input_feat: (3535, 100, 5)
  加载 masif_rho_wrt_center: (3535, 100)
  加载 masif_theta_wrt_center: (3535, 100)
  加载 masif_mask: (3535, 100)
  加载 masif_desc_straight: (3535, 80)
  加载 masif_desc_flipped: (3535, 80)
找到目标复合物: 2aco-VCA
保存整合后的PKL文件到: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/2aco-VCA_features_with_masif.pkl
整合完成!
MaSIF特征总结:
  - masif_input_feat: (3535, 100, 5)
  - masif_rho_wrt_center: (3535, 100)
  - masif_theta_wrt_center: (3535, 100)
  - masif_mask: (3535, 100)
  - masif_desc_straight: (3535, 80)
  - masif_desc_flipped: (3535, 80)
整合成功!
----------------------------------------
All processing completed!

# %%
zncao02@f101$  bash preprocess.sh ./data/2aco.csv 
Processing: 2aco-VCA
Target directory: /xcfhome/zncao02/affincraft/data/2aco-VCA
Output directory: /xcfhome/zncao02/affincraft/data/2aco-VCA/output
Step 1: Running custom_input.py...
100%|██████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 25.00it/s]
Warning: use "from pymol import cmd" instead of "import cmd"
正在进行PLIP分析: 2aco-VCA
PLIP分析结果类型: <class 'dict'>
发现的结合位点数: 1
lig_ea shape: (38, 4)
pro_ea shape: (176, 4)
lig_sea shape: (102, 4)
pro_sea shape: (886, 4)
lig_pock_ea shape: (22, 4)
Generated PKL file: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/2aco-VCA_features.pkl
Detected protein chain: B
Step 2: Running meshfeatureGen.py...
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/prody/utilities/misctools.py:411: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
  import pkg_resources
开始蛋白质-配体表面特征计算...
质子化PDB文件...
提取链 B...
计算MSMS分子表面...
处理配体 UNK...
DEBUG: Reading ligand from SDF file: /xcfhome/zncao02/affincraft/data/2aco-VCA/ligand.sdf
DEBUG: Using modified amide_to_single_bond function
[OK] Atom names fixed in /xcfhome/zncao02/affincraft/data/2aco-VCA/output/tmp/UNK_X.mol2
[OK] SDF to MOL2 conversion and cleaning done: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/tmp/UNK_X.mol2
成功生成 MOL2 文件: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/tmp/UNK_X.mol2
计算化学特征...
  - 计算氢键特征...
  - 计算疏水性特征...
修复和正则化网格...
Removing degenerated triangles
网格修复完成!
计算几何特征...
计算APBS静电特征...
### PDB2PQR ###
 Warning: multiple occupancies found: O1 in LIG L 1
Warning: multiple occupancies found: C1 in LIG L 1
Warning: multiple occupancies found: O2 in LIG L 1
Warning: multiple occupancies found: C2 in LIG L 1
Warning: multiple occupancies found: C3 in LIG L 1
Warning: multiple occupancies found: C4 in LIG L 1
Warning: multiple occupancies found: C5 in LIG L 1
Warning: multiple occupancies found: C6 in LIG L 1
Warning: multiple occupancies found: C7 in LIG L 1
Warning: multiple occupancies found: C8 in LIG L 1
Warning: multiple occupancies found: C9 in LIG L 1
Warning: multiple occupancies found: C10 in LIG L 1
Warning: multiple occupancies found: C11 in LIG L 1
Warning: multiple occupancies found: C12 in LIG L 1
Warning: multiple occupancies found: C13 in LIG L 1
Warning: multiple occupancies found: C14 in LIG L 1
Warning: multiple occupancies found: C15 in LIG L 1
Warning: multiple occupancies found: C16 in LIG L 1
Warning: multiple occupancies found: C17 in LIG L 1
Warning: multiple occupancies found: C18 in LIG L 1
Warning: multiple occupancies found: H1 in LIG L 1
Warning: multiple occupancies found: H2 in LIG L 1
Warning: multiple occupancies found: H3 in LIG L 1
Warning: multiple occupancies found: H4 in LIG L 1
Warning: multiple occupancies found: H5 in LIG L 1
Warning: multiple occupancies found: H6 in LIG L 1
Warning: multiple occupancies found: H7 in LIG L 1
Warning: multiple occupancies found: H8 in LIG L 1
Warning: multiple occupancies found: H9 in LIG L 1
Warning: multiple occupancies found: H10 in LIG L 1
Warning: multiple occupancies found: H11 in LIG L 1
Warning: multiple occupancies found: H12 in LIG L 1
Warning: multiple occupancies found: H13 in LIG L 1
Warning: multiple occupancies found: H14 in LIG L 1
Warning: multiple occupancies found: H15 in LIG L 1
Warning: multiple occupancies found: H16 in LIG L 1
Warning: multiple occupancies found: H17 in LIG L 1
Warning: multiple occupancies found: H18 in LIG L 1
Warning: multiple occupancies found: H19 in LIG L 1
Warning: multiple occupancies found: H20 in LIG L 1
Warning: multiple occupancies found: H21 in LIG L 1
Warning: multiple occupancies found: H22 in LIG L 1
Warning: multiple occupancies found: H23 in LIG L 1
Warning: multiple occupancies found: H24 in LIG L 1
Warning: multiple occupancies found: H25 in LIG L 1
Warning: multiple occupancies found: H26 in LIG L 1
Warning: multiple occupancies found: H27 in LIG L 1
Warning: multiple occupancies found: H28 in LIG L 1
Warning: multiple occupancies found: H29 in LIG L 1
Warning: multiple occupancies found: H30 in LIG L 1
Warning: multiple occupancies found: H31 in LIG L 1
Warning: multiple occupancies found: H32 in LIG L 1
Warning: multiple occupancies found: H33 in LIG L 1

### APBS ###
 
### MULTIVALUE ###
 
APBS计算完成!
计算界面特征...
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'TER' at line 2713
  warnings.warn(
计算曲率和形状特征...
构建增强特征字典...
表面特征计算完成!
顶点数: 3444
面数: 6884
特征维度: 11
Step 3: Running feature_precompute.py...
开始Step 3: 特征预计算...
处理PLY文件: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/surfaces/complex_B.ply
输出目录: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/precomputed/complex_B/
读取表面数据并计算patch特征...
Dijkstra took 3.10s
Only MDS time: 31.77s
Full loop time: 38.00s
MDS took 38.00s
成功计算特征:
  - 顶点数: 3444
  - 输入特征维度: (3444, 100, 5)
  - 极坐标 rho: (3444, 100)
  - 极坐标 theta: (3444, 100)
  - 邻居索引: 3444
保存预计算特征...
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
  return array(a, dtype, copy=False, order=order, subok=True)
特征保存完成!
Step 3完成! 生成了 3444 个patches，每个patch有 5 维特征
Step 4: Running fingerprint_gen.py...
2025-07-16 14:44:34.081570: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
2025-07-16 14:44:35.850178: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
E0000 00:00:1752648276.172270 1231328 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
E0000 00:00:1752648276.461440 1231328 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
W0000 00:00:1752648277.461400 1231328 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752648277.461449 1231328 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752648277.461454 1231328 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
W0000 00:00:1752648277.461458 1231328 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
2025-07-16 14:44:37.594211: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
WARNING:tensorflow:From /xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
Instructions for updating:
non-resource variables are not supported in the long term
开始Step 4: 基于神经网络的指纹生成...
从目录加载预计算特征: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/precomputed/complex_B
警告: 无法加载自定义参数文件 masif.source.masif_ppi_search.nn_models.sc05.all_feat.custom_params: No module named 'masif.source.masif_ppi_search.nn_models'
将使用默认参数。
加载预训练的神经网络模型...
(80, 2)
I0000 00:00:1752648338.633942 1231328 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 450 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:3b:00.0, compute capability: 8.6
I0000 00:00:1752648338.635673 1231328 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 22052 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:d8:00.0, compute capability: 8.6
WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
I0000 00:00:1752648339.028123 1231328 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
<tf.Variable 'mu_rho_0:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_theta_0:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_rho_0:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_theta_0:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_rho_1:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_theta_1:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_rho_1:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_theta_1:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_rho_2:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_theta_2:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_rho_2:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_theta_2:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_rho_3:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_theta_3:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_rho_3:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_theta_3:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_rho_4:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'mu_theta_4:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_rho_4:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'sigma_theta_4:0' shape=(1, 80) dtype=float32_ref>
80
<tf.Variable 'b_conv_0:0' shape=(80,) dtype=float32_ref>
80
<tf.Variable 'b_conv_1:0' shape=(80,) dtype=float32_ref>
80
<tf.Variable 'b_conv_2:0' shape=(80,) dtype=float32_ref>
80
<tf.Variable 'b_conv_3:0' shape=(80,) dtype=float32_ref>
80
<tf.Variable 'b_conv_4:0' shape=(80,) dtype=float32_ref>
80
<tf.Variable 'W_conv_0:0' shape=(80, 80) dtype=float32_ref>
6400
<tf.Variable 'W_conv_1:0' shape=(80, 80) dtype=float32_ref>
6400
<tf.Variable 'W_conv_2:0' shape=(80, 80) dtype=float32_ref>
6400
<tf.Variable 'W_conv_3:0' shape=(80, 80) dtype=float32_ref>
6400
<tf.Variable 'W_conv_4:0' shape=(80, 80) dtype=float32_ref>
6400
<tf.Variable 'fully_connected/weights:0' shape=(400, 80) dtype=float32_ref>
32000
<tf.Variable 'fully_connected/biases:0' shape=(80,) dtype=float32_ref>
80
Total number parameters: 66080
使用绝对路径加载模型: /xcfhome/zncao02/affincraft/masif/data/masif_ppi_search/nn_models/sc05/all_feat/model_data/
神经网络模型加载成功。
预计算特征数据加载成功。
计算表面描述符 (指纹)...
描述符计算完成，耗时: 13.20s
表面指纹已保存到: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/descriptors/complex_B
Step 4完成! 生成了 3444 个指纹，每个指纹维度为 80。
\n=== Step 4 输出指纹总结 ===
标准方向指纹形状: (3444, 80)
翻转方向指纹形状: (3444, 80)
指纹文件保存在: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/descriptors/complex_B
Step 5: Merging MaSIF features to existing PKL...
加载现有PKL文件: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/2aco-VCA_features.pkl
现有PKL文件包含 1 个复合物
加载MaSIF特征...
  加载 masif_input_feat: (3444, 100, 5)
  加载 masif_rho_wrt_center: (3444, 100)
  加载 masif_theta_wrt_center: (3444, 100)
  加载 masif_mask: (3444, 100)
  加载 masif_desc_straight: (3444, 80)
  加载 masif_desc_flipped: (3444, 80)
找到目标复合物: 2aco-VCA
保存整合后的PKL文件到: /xcfhome/zncao02/affincraft/data/2aco-VCA/output/2aco-VCA_features_with_masif.pkl
整合完成!
MaSIF特征总结:
  - masif_input_feat: (3444, 100, 5)
  - masif_rho_wrt_center: (3444, 100)
  - masif_theta_wrt_center: (3444, 100)
  - masif_mask: (3444, 100)
  - masif_desc_straight: (3444, 80)
  - masif_desc_flipped: (3444, 80)
整合成功!
----------------------------------------
All processing completed!
