# %%
import tensorflow as tf  
from tensorflow.python.tools import inspect_checkpoint as chkp  
  

chkp.print_tensors_in_checkpoint_file("/xcfhome/zncao02/test/masif-neosurf/masif/data/masif_ppi_search/nn_models/sc05/all_feat/model_data/model", tensor_name='', all_tensors=True)
# Out:
# tensor: W_conv_0 (float32) [80, 80]
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# tensor: W_conv_0/Adam (float32) [80, 80]
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# tensor: W_conv_0/Adam_1 (float32) [80, 80]
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# tensor: W_conv_1 (float32) [80, 80]
# [[-7.0135969e-01 -2.6558164e-01  2.5149006e-01 ... -1.9853151e-01
#    7.1703136e-02  2.4528642e-01]
#  [-4.8685065e-01 -4.5281304e-03  3.0104512e-01 ... -1.3137707e-02
#    2.2838436e-01 -4.1032478e-02]
# ...

# %%
import tensorflow.compat.v1 as tf  
tf.disable_v2_behavior()  
from tensorflow.python.tools import inspect_checkpoint as chkp  
  
# 检查checkpoint中的变量名  
chkp.print_tensors_in_checkpoint_file(  
    "/xcfhome/zncao02/AffinSculptor/masif/data/masif_ppi_search/nn_models/sc05/all_feat/model_data/model",   
    tensor_name='',   
    all_tensors=True  
)
# Out:
# tensor: W_conv_0 (float32) [80, 80]
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# tensor: W_conv_0/Adam (float32) [80, 80]
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# tensor: W_conv_0/Adam_1 (float32) [80, 80]
# [[nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  ...
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]
#  [nan nan nan ... nan nan nan]]
# tensor: W_conv_1 (float32) [80, 80]
# [[-7.0135969e-01 -2.6558164e-01  2.5149006e-01 ... -1.9853151e-01
#    7.1703136e-02  2.4528642e-01]
#  [-4.8685065e-01 -4.5281304e-03  3.0104512e-01 ... -1.3137707e-02
#    2.2838436e-01 -4.1032478e-02]
# ...
