# %% [markdown]
# ## step 1&2

# %%
##这是一个非常实用的需求！你可以通过以下几种方法，实现在激活 dynaformer 这个 conda 环境时，自动 export 这些变量：##

方法一：使用 conda 的 etc/conda/activate.d 机制（推荐）
每个 conda 环境下都有
$CONDA_PREFIX/etc/conda/activate.d/
和
$CONDA_PREFIX/etc/conda/deactivate.d/
两个目录，可以用来在环境激活/关闭时自动执行脚本。

步骤
激活你的环境

bash

复制
conda activate dynaformer
创建目录（如果没有）

bash

复制
mkdir -p $CONDA_PREFIX/etc/conda/activate.d
新建脚本
比如新建：

bash

复制
nano $CONDA_PREFIX/etc/conda/activate.d/env_vars.sh
或用 vim/edit 等。

把你的 export 语句全部加进去

bash

复制
export APBS_BIN=/xcfhome/zncao02/software/APBS-3.0.0.Linux/bin/apbs
export MULTIVALUE_BIN=/xcfhome/zncao02/software/APBS-3.0.0.Linux/share/apbs/tools/bin/multivalue
export PDB2PQR_BIN=/xcfhome/zncao02/software/pdb2pqr-linux-bin64-2.1.0/pdb2pqr
export REDUCE_HET_DICT=/xcfhome/zncao02/software/reduce_wwPDB_het_dict.txt
export PYMESH_PATH=/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/pymesh
export MSMS_BIN=/xcfhome/zncao02/software/msms/msms.x86_64Linux2.2.6.1
export PDB2XYZRN=/xcfhome/zncao02/software/msms/pdb_to_xyzrn
export LD_LIBRARY_PATH=/xcfhome/zncao02/software/APBS-3.0.0.Linux/lib:$LD_LIBRARY_PATH
export PATH=$PATH:/xcfhome/zncao02/software/reduce_bin
保存退出即可！

# %%
你的报错：


复制
ModuleNotFoundError: No module named 'PyMesh'
即使你 pip install PyMesh 后依然出错，原因在于 PyMesh 的 Python 包和 C++ 后端安装体系比较特殊，仅 pip install PyMesh 并不能直接用，尤其是 import PyMesh。

1. PyMesh vs pymesh
pymesh 这个包的安装，只会安装 Python 接口代码，但它依赖的核心库 PyMesh（通常是 C++ 编译出来的 .so/.pyd 文件）需要额外编译和配置。
官方 PyMesh 安装文档 推荐源码编译（不是 pip）。
你现在遇到的 import PyMesh 报错，就是因为 PyMesh 的动态库没装好。

# %%
zncao02@f100$ p /xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py", line 15, in <module>
    from triangulation.ligand_utils import extract_ligand
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/ligand_utils.py", line 7, in <module>
    import prody
ModuleNotFoundError: No module named 'prody'

# %%
 p /xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/prody/utilities/misctools.py:424: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.  
  import pkg_resources                                                                 
开始蛋白质-配体表面特征计算...
质子化PDB文件...
提取链 A...
计算MSMS分子表面...
处理配体 UNK...
Traceback (most recent call last):
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/prody/proteins/pdbfile.py", line 1186, in writePDBStream
    coordsets = atoms._getCoordsets(csets)
AttributeError: 'NoneType' object has no attribute '_getCoordsets'

During handling of the above exception, another exception occurred:

Traceback (most recent call last):
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/prody/proteins/pdbfile.py", line 1189, in writePDBStream
    coordsets = atoms._getCoords()
AttributeError: 'NoneType' object has no attribute '_getCoords'

During handling of the above exception, another exception occurred:

Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py", line 244, in <module>
    result = compute_protein_ligand_surface_features(
  File "/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py", line 77, in compute_protein_ligand_surface_features
    rdmol = extract_ligand(
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/ligand_utils.py", line 61, in extract_ligand
    prody.writePDBStream(out, ligand)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/prody/proteins/pdbfile.py", line 1191, in writePDBStream
    raise TypeError('atoms must be an object with coordinate sets')
TypeError: atoms must be an object with coordinate sets

# %%
 p '/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py'
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/prody/utilities/misctools.py:424: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
  import pkg_resources
开始蛋白质-配体表面特征计算...
质子化PDB文件...
提取链 A...
计算MSMS分子表面...
处理配体 UNK...
Mismatch between PDB and SDF ligands. Determining bond types with OpenBabel...
==============================
*** Open Babel Warning  in PerceiveBondOrders
  Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders

[16:50:19] WARNING: More than one matching pattern found - picking one
==============================
*** Open Babel Warning  in PerceiveBondOrders
  Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders

The molecule must be protonated!
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py", line 244, in <module>
    result = compute_protein_ligand_surface_features(
  File "/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py", line 77, in compute_protein_ligand_surface_features
    rdmol = extract_ligand(
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/ligand_utils.py", line 97, in extract_ligand
    assert rdmol.GetNumHeavyAtoms() < rdmol.GetNumAtoms(), \
AssertionError: None

# %%
zncao02@f100$ p '/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py'
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/prody/utilities/misctools.py:424: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
  import pkg_resources
开始蛋白质-配体表面特征计算...
质子化PDB文件...
提取链 A...
计算MSMS分子表面...
处理配体 UNK...
==============================
*** Open Babel Warning  in PerceiveBondOrders
  Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders

The molecule must be protonated!
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py", line 244, in <module>
    result = compute_protein_ligand_surface_features(
  File "/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py", line 77, in compute_protein_ligand_surface_features
    rdmol = extract_ligand(
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/ligand_utils.py", line 97, in extract_ligand
    assert rdmol.GetNumHeavyAtoms() < rdmol.GetNumAtoms(), \
AssertionError: None

# %%
p '/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py'
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/prody/utilities/misctools.py:424: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
  import pkg_resources
开始蛋白质-配体表面特征计算...
质子化PDB文件...
提取链 A...
计算MSMS分子表面...
处理配体 UNK...
==============================
*** Open Babel Warning  in PerceiveBondOrders
  Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders

成功提取配体 UNK
计算化学特征...
  - 计算氢键特征...
[19:41:07] 

****
Pre-condition Violation
RingInfo not initialized
Violation occurred on line 45 in file /tmp/pip-req-build-kf8yzk_q/build/temp.linux-x86_64-3.9/rdkit/Code/GraphMol/RingInfo.cpp
Failed Expression: df_init
****

Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py", line 244, in <module>
    result = compute_protein_ligand_surface_features(
  File "/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py", line 99, in compute_protein_ligand_surface_features
    vertex_hbond = computeCharges(out_filename, vertices1, names1, ligand_code, rdmol)
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/computeCharges.py", line 50, in computeCharges
    rdmol, name_to_idx, donorHs, acceptors = prepare_rdmol(rdmol)
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/ligand_charges.py", line 148, in prepare_rdmol
    donor_hydrogens = get_donor_hydrogens(mol)
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/ligand_charges.py", line 129, in get_donor_hydrogens
    donors = get_donors(mol)
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/ligand_charges.py", line 123, in get_donors
    feats = featFact.GetFeaturesForMol(mol)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/rdkit/Chem/ChemicalFeatures.py", line 16, in MCFF_GetFeaturesForMol
    count = self.GetNumMolFeatures(mol, includeOnly=includeOnly)
RuntimeError: Pre-condition Violation
        RingInfo not initialized
        Violation occurred on line 45 in file Code/GraphMol/RingInfo.cpp
        Failed Expression: df_init
        RDKIT: 2021.09.3
        BOOST: 1_76

# %%
zncao02@f100$ p '/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py'
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/prody/utilities/misctools.py:424: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
  import pkg_resources
开始蛋白质-配体表面特征计算...
质子化PDB文件...
提取链 A...
计算MSMS分子表面...
处理配体 UNK...
DEBUG: Reading ligand from SDF file: ligand.sdf
DEBUG: Successfully read molecule from SDF
DEBUG: Total atoms: 32
DEBUG: Heavy atoms: 19
DEBUG: Has hydrogens: True
DEBUG: First 10 atoms:
  Atom 0: O (atomic num: 8)
  Atom 1: C (atomic num: 6)
  Atom 2: C (atomic num: 6)
  Atom 3: O (atomic num: 8)
  Atom 4: C (atomic num: 6)
  Atom 5: O (atomic num: 8)
  Atom 6: C (atomic num: 6)
  Atom 7: O (atomic num: 8)
  Atom 8: C (atomic num: 6)
  Atom 9: N (atomic num: 7)
DEBUG: Attempting molecule sanitization...
DEBUG: Sanitization successful
成功生成 MOL2 文件: ./output/tmp/UNK_X.mol2
计算化学特征...
  - 计算氢键特征...
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py", line 254, in <module>
    result = compute_protein_ligand_surface_features(
  File "/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py", line 109, in compute_protein_ligand_surface_features
    vertex_hbond = computeCharges(out_filename, vertices1, names1, ligand_code, rdmol)
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/computeCharges.py", line 50, in computeCharges
    rdmol, name_to_idx, donorHs, acceptors = prepare_rdmol(rdmol)
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/ligand_charges.py", line 146, in prepare_rdmol
    name_to_idx = {a.GetPDBResidueInfo().GetName().strip(): a.GetIdx()
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/ligand_charges.py", line 146, in <dictcomp>
    name_to_idx = {a.GetPDBResidueInfo().GetName().strip(): a.GetIdx()
AttributeError: 'NoneType' object has no attribute 'GetName'

# %%
  import pkg_resources
开始蛋白质-配体表面特征计算...
质子化PDB文件...
提取链 A...
计算MSMS分子表面...
处理配体 UNK...
DEBUG: Reading ligand from SDF file: ligand.sdf
DEBUG: Attempting molecule sanitization...
DEBUG: Sanitization successful
成功生成 MOL2 文件: ./output/tmp/UNK_X.mol2
计算化学特征...
  - 计算氢键特征...
Atom 'C' not found in ligand UNK
Atom 'C' not found in ligand UNK
Atom 'C' not found in ligand UNK
Atom 'C' not found in ligand UNK
Atom 'C' not found in ligand UNK
Atom 'C' not found in ligand UNK
Atom 'C' not found in ligand UNK
  - 计算疏水性特征...
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py", line 254, in <module>
    result = compute_protein_ligand_surface_features(
  File "/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py", line 114, in compute_protein_ligand_surface_features
    vertex_hphobicity = computeHydrophobicity(names1, ligand_code, rdmol)
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/computeHydrophobicity.py", line 99, in computeHydrophobicity
    hp[ix] = mol_kd[atom_name]
KeyError: 'C'

# %%
开始蛋白质-配体表面特征计算...
质子化PDB文件...
提取链 A...
计算MSMS分子表面...
处理配体 UNK...
DEBUG: Reading ligand from SDF file: ligand.sdf
DEBUG: Attempting molecule sanitization...
DEBUG: Sanitization successful
成功生成 MOL2 文件: ./output/tmp/UNK_X.mol2
计算化学特征...
  - 计算氢键特征...
  - 计算疏水性特征...
修复和正则化网格...
Removing degenerated triangles
网格修复完成!
计算几何特征...
计算APBS静电特征...
### PDB2PQR ###
 Usage: pdb2pqr [options] PDB_PATH PQR_OUTPUT_PATH

pdb2pqr: error: --apbs-input option does not take a value

### APBS ###
 Vio_ctor2: some error occurred.
Vio_ctor: Vio_ctor2() failed.
Error while opening input file complex_A.in!

### MULTIVALUE ###
 Vio_ctor2: some error occurred.
Vio_ctor: Vio_ctor2() failed.
Vgrid_readDX: Problem opening virtual socket complex_A.dx
main:  Problem reading standard OpenDX-format grid from complex_A.dx

Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py", line 254, in <module>
    result = compute_protein_ligand_surface_features(
  File "/xcfhome/zncao02/AffinSculptor/masif/extract_feature_triang.py", line 142, in compute_protein_ligand_surface_features
    vertex_charges = computeAPBS(
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/computeAPBS.py", line 64, in computeAPBS
    chargefile = open(tmp_file_base + "_out.csv")
FileNotFoundError: [Errno 2] No such file or directory: './output/tmp//complex_A_out.csv'

# %% [markdown]
# ## Step 3

# %%
zncao02@f100$ p '/xcfhome/zncao02/AffinSculptor/masif/masif_precompute.py'
开始Step 3: 特征预计算...
处理PLY文件: ./output/tmp/complex_A.ply
输出目录: ./output/precomputed/complex_A/
读取表面数据并计算patch特征...
特征计算失败: module 'time' has no attribute 'clock'

zncao02@f100$ p '/xcfhome/zncao02/AffinSculptor/masif/masif_precompute.py'
开始Step 3: 特征预计算...
处理PLY文件: ./output/tmp/complex_A.ply
输出目录: ./output/precomputed/complex_A/
读取表面数据并计算patch特征...
Dijkstra took 3.51s
特征计算失败: np.matrix is not supported. Please convert to a numpy array with np.asarray. 
For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html

# %% [markdown]
# ## Step 4

# %%
To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
开始Step 4: 基于神经网络的指纹生成...
从目录加载预计算特征: ./output/precomputed/complex_A/
加载自定义参数文件: masif_ppi_search.nn_models.sc05.all_feat.custom_params
加载预训练的神经网络模型...
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
    fingerprints = generate_surface_fingerprints(
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
    learning_obj = MaSIF_ppi_search(
  File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 200, in __init__
    tf.set_random_seed(0)
AttributeError: module 'tensorflow' has no attribute 'set_random_seed'

# %%
开始Step 4: 基于神经网络的指纹生成...
从目录加载预计算特征: ./output/precomputed/complex_A/
加载自定义参数文件: masif_ppi_search.nn_models.sc05.all_feat.custom_params
加载预训练的神经网络模型...
(80, 2)
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
    fingerprints = generate_surface_fingerprints(
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
    learning_obj = MaSIF_ppi_search(
  File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 273, in __init__
    desc = self.inference(
  File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 86, in inference
    thetas_coords_ = tf.mod(thetas_coords_, 2 * np.pi)
AttributeError: module 'tensorflow' has no attribute 'mod

# %%
开始Step 4: 基于神经网络的指纹生成...
从目录加载预计算特征: ./output/precomputed/complex_A/
加载自定义参数文件: masif_ppi_search.nn_models.sc05.all_feat.custom_params
加载预训练的神经网络模型...
(80, 2)
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
    fingerprints = generate_surface_fingerprints(
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
    learning_obj = MaSIF_ppi_search(
  File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 273, in __init__
    desc = self.inference(
  File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 105, in inference
    tf.reduce_sum(gauss_activations, 1, keep_dims=True) + eps
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/ops/weak_tensor_ops.py", line 88, in wrapper
    return op(*args, **kwargs)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py", line 153, in error_handler
    raise e.with_traceback(filtered_tb) from None
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/util/dispatch.py", line 1254, in op_dispatch_handler
    result = api_dispatcher.Dispatch(args, kwargs)
TypeError: Got an unexpected keyword argument 'keep_dims'

# %%
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
    fingerprints = generate_surface_fingerprints(
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
    learning_obj = MaSIF_ppi_search(
  File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 310, in __init__
    self.var_grad = tf.gradients(self.data_loss, tf.compat.v1.trainable_variables())
AttributeError: module 'tensorflow' has no attribute 'trainable_variables'

# %%
Traceback (most recent call last):
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1407, in _do_call
    return fn(*args)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1390, in _run_fn
    return self._call_tf_sessionrun(options, feed_dict, fetch_list,
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1483, in _call_tf_sessionrun
    return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
tensorflow.python.framework.errors_impl.NotFoundError: 2 root error(s) found.
  (0) NOT_FOUND: Key dense/bias not found in checkpoint
         [[{{node save/RestoreV2}}]]
         [[save/RestoreV2/_87]]
  (1) NOT_FOUND: Key dense/bias not found in checkpoint
         [[{{node save/RestoreV2}}]]
0 successful operations.
0 derived errors ignored.

During handling of the above exception, another exception occurred:

Traceback (most recent call last):
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 1422, in restore
    sess.run(self.saver_def.restore_op_name,
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 977, in run
    result = self._run(None, fetches, feed_dict, options_ptr,
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1220, in _run
    results = self._do_run(handle, final_targets, final_fetches,
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1400, in _do_run
    return self._do_call(_run_fn, feeds, fetches, targets, options,
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1426, in _do_call
    raise type(e)(node_def, op, message)  # pylint: disable=no-value-for-parameter
tensorflow.python.framework.errors_impl.NotFoundError: Graph execution error:

Detected at node 'save/RestoreV2' defined at (most recent call last):
    File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
    File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
    File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 323, in __init__
Node: 'save/RestoreV2'
Detected at node 'save/RestoreV2' defined at (most recent call last):
    File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
    File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
    File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 323, in __init__
Node: 'save/RestoreV2'
2 root error(s) found.
  (0) NOT_FOUND: Key dense/bias not found in checkpoint
         [[{{node save/RestoreV2}}]]
         [[save/RestoreV2/_87]]
  (1) NOT_FOUND: Key dense/bias not found in checkpoint
         [[{{node save/RestoreV2}}]]
0 successful operations.
0 derived errors ignored.

Original stack trace for 'save/RestoreV2':
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
  File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 323, in __init__
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 934, in __init__
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 946, in build
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 974, in _build
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 543, in _build_internal
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 360, in _AddRestoreOps
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 611, in bulk_restore
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1522, in restore_v2
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/framework/op_def_library.py", line 796, in _apply_op_helper
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 2705, in _create_op_internal
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 1200, in from_node_def


During handling of the above exception, another exception occurred:

Traceback (most recent call last):
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/py_checkpoint_reader.py", line 66, in get_tensor
    return CheckpointReader.CheckpointReader_GetTensor(
RuntimeError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint

During handling of the above exception, another exception occurred:

Traceback (most recent call last):
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 1433, in restore
    names_to_keys = object_graph_key_mapping(save_path)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 1755, in object_graph_key_mapping
    object_graph_string = reader.get_tensor(trackable.OBJECT_GRAPH_PROTO_KEY)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/py_checkpoint_reader.py", line 71, in get_tensor
    error_translator(e)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/py_checkpoint_reader.py", line 31, in error_translator
    raise errors_impl.NotFoundError(None, None, error_message)
tensorflow.python.framework.errors_impl.NotFoundError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint

During handling of the above exception, another exception occurred:

Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
    fingerprints = generate_surface_fingerprints(
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 66, in generate_surface_fingerprints
    learning_obj.saver.restore(learning_obj.session, model_path)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 1438, in restore
    raise _wrap_restore_error_with_msg(
tensorflow.python.framework.errors_impl.NotFoundError: Restoring from checkpoint failed. This is most likely due to a Variable name or other graph key that is missing from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:

Graph execution error:

Detected at node 'save/RestoreV2' defined at (most recent call last):
    File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
    File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
    File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 323, in __init__
Node: 'save/RestoreV2'
Detected at node 'save/RestoreV2' defined at (most recent call last):
    File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
    File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
    File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 323, in __init__
Node: 'save/RestoreV2'
2 root error(s) found.
  (0) NOT_FOUND: Key dense/bias not found in checkpoint
         [[{{node save/RestoreV2}}]]
         [[save/RestoreV2/_87]]
  (1) NOT_FOUND: Key dense/bias not found in checkpoint
         [[{{node save/RestoreV2}}]]
0 successful operations.
0 derived errors ignored.

Original stack trace for 'save/RestoreV2':
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
  File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 323, in __init__
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 934, in __init__
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 946, in build
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 974, in _build
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 543, in _build_internal
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 360, in _AddRestoreOps
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 611, in bulk_restore
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1522, in restore_v2
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/framework/op_def_library.py", line 796, in _apply_op_helper
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 2705, in _create_op_internal
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 1200, in from_node_def

# %%
开始Step 4: 基于神经网络的指纹生成...
从目录加载预计算特征: /xcfhome/zncao02/dataset_bap/test_set/custom/2wh8-II2/output/precomputed/complex_A/
加载自定义参数文件: masif_ppi_search.nn_models.sc05.all_feat.custom_params
加载预训练的神经网络模型...
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
    fingerprints = generate_surface_fingerprints(
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
    learning_obj = MaSIF_ppi_search(
  File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 200, in __init__
    tf.random.set_seed(0)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/util/module_wrapper.py", line 232, in _getattr
    attr = getattr(self._tfmw_wrapped_module, name)
AttributeError: module 'tensorflow._api.v2.compat.v1.random' has no attribute 'set_seed'

# %%
Traceback (most recent call last):
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1407, in _do_call
    return fn(*args)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1390, in _run_fn
    return self._call_tf_sessionrun(options, feed_dict, fetch_list,
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1483, in _call_tf_sessionrun
    return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
tensorflow.python.framework.errors_impl.NotFoundError: 2 root error(s) found.
  (0) NOT_FOUND: Key dense/bias not found in checkpoint
         [[{{node save/RestoreV2}}]]
         [[save/RestoreV2/_9]]
  (1) NOT_FOUND: Key dense/bias not found in checkpoint
         [[{{node save/RestoreV2}}]]
0 successful operations.
0 derived errors ignored.

During handling of the above exception, another exception occurred:

Traceback (most recent call last):
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 1422, in restore
    sess.run(self.saver_def.restore_op_name,
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 977, in run
    result = self._run(None, fetches, feed_dict, options_ptr,
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1220, in _run
    results = self._do_run(handle, final_targets, final_fetches,
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1400, in _do_run
    return self._do_call(_run_fn, feeds, fetches, targets, options,
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/client/session.py", line 1426, in _do_call
    raise type(e)(node_def, op, message)  # pylint: disable=no-value-for-parameter
tensorflow.python.framework.errors_impl.NotFoundError: Graph execution error:

Detected at node 'save/RestoreV2' defined at (most recent call last):
    File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
    File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
    File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 335, in __init__
Node: 'save/RestoreV2'
Detected at node 'save/RestoreV2' defined at (most recent call last):
    File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
    File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
    File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 335, in __init__
Node: 'save/RestoreV2'
2 root error(s) found.
  (0) NOT_FOUND: Key dense/bias not found in checkpoint
         [[{{node save/RestoreV2}}]]
         [[save/RestoreV2/_9]]
  (1) NOT_FOUND: Key dense/bias not found in checkpoint
         [[{{node save/RestoreV2}}]]
0 successful operations.
0 derived errors ignored.

Original stack trace for 'save/RestoreV2':
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
  File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 335, in __init__
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 934, in __init__
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 946, in build
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 974, in _build
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 543, in _build_internal
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 360, in _AddRestoreOps
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 611, in bulk_restore
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1522, in restore_v2
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/framework/op_def_library.py", line 796, in _apply_op_helper
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 2705, in _create_op_internal
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 1200, in from_node_def


During handling of the above exception, another exception occurred:

Traceback (most recent call last):
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/py_checkpoint_reader.py", line 66, in get_tensor
    return CheckpointReader.CheckpointReader_GetTensor(
RuntimeError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint

During handling of the above exception, another exception occurred:

Traceback (most recent call last):
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 1433, in restore
    names_to_keys = object_graph_key_mapping(save_path)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 1755, in object_graph_key_mapping
    object_graph_string = reader.get_tensor(trackable.OBJECT_GRAPH_PROTO_KEY)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/py_checkpoint_reader.py", line 71, in get_tensor
    error_translator(e)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/py_checkpoint_reader.py", line 31, in error_translator
    raise errors_impl.NotFoundError(None, None, error_message)
tensorflow.python.framework.errors_impl.NotFoundError: Key _CHECKPOINTABLE_OBJECT_GRAPH not found in checkpoint

During handling of the above exception, another exception occurred:

Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
    fingerprints = generate_surface_fingerprints(
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 66, in generate_surface_fingerprints
    learning_obj.saver.restore(learning_obj.session, model_path)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 1438, in restore
    raise _wrap_restore_error_with_msg(
tensorflow.python.framework.errors_impl.NotFoundError: Restoring from checkpoint failed. This is most likely due to a Variable name or other graph key that is missing from the checkpoint. Please ensure that you have not altered the graph expected based on the checkpoint. Original error:

Graph execution error:

Detected at node 'save/RestoreV2' defined at (most recent call last):
    File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
    File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
    File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 335, in __init__
Node: 'save/RestoreV2'
Detected at node 'save/RestoreV2' defined at (most recent call last):
    File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
    File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
    File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 335, in __init__
Node: 'save/RestoreV2'
2 root error(s) found.
  (0) NOT_FOUND: Key dense/bias not found in checkpoint
         [[{{node save/RestoreV2}}]]
         [[save/RestoreV2/_9]]
  (1) NOT_FOUND: Key dense/bias not found in checkpoint
         [[{{node save/RestoreV2}}]]
0 successful operations.
0 derived errors ignored.

Original stack trace for 'save/RestoreV2':
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 148, in <module>
  File "/xcfhome/zncao02/AffinSculptor/masif/fingerprint_gen.py", line 51, in generate_surface_fingerprints
  File "/xcfhome/zncao02/AffinSculptor/masif/source/masif_modules/MaSIF_ppi_search.py", line 335, in __init__
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 934, in __init__
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 946, in build
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 974, in _build
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 543, in _build_internal
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 360, in _AddRestoreOps
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/training/saver.py", line 611, in bulk_restore
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/ops/gen_io_ops.py", line 1522, in restore_v2
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/framework/op_def_library.py", line 796, in _apply_op_helper
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 2705, in _create_op_internal
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 1200, in from_node_def

# %% [markdown]
# ## merge

# %%
zncao02@f130$ bash preprocess.sh data/example.csv 
Processing: 6v16-QMG
Target directory: /xcfhome/zncao02/dataset_bap/test_set/custom/6v16-QMG
Output directory: /xcfhome/zncao02/dataset_bap/test_set/custom/6v16-QMG/output
Step 1: Running custom_input.py...
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/preprocess/custom_input.py", line 5, in <module>
    from preprocess import  gen_graph, to_pyg_graph, get_info, RF_score, GB_score,  analyze_plip_interactions  # 预处理和特征生成相关函数
  File "/xcfhome/zncao02/AffinSculptor/preprocess/preprocess.py", line 9, in <module>
    from ecif import GetECIF  
  File "/xcfhome/zncao02/AffinSculptor/preprocess/ecif.py", line 85, in <module>
    Atom_Keys = pd.read_csv("PDB_Atom_Keys.csv", sep=",")  # PDB 原子名到 ECIF 类型的映射表
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 912, in read_csv
    return _read(filepath_or_buffer, kwds)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 577, in _read
    parser = TextFileReader(filepath_or_buffer, **kwds)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 1407, in __init__
    self._engine = self._make_engine(f, self.engine)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 1661, in _make_engine
    self.handles = get_handle(
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/pandas/io/common.py", line 859, in get_handle
    handle = open(
FileNotFoundError: [Errno 2] No such file or directory: 'PDB_Atom_Keys.csv'
preprocess.sh: line 32: --receptor: command not found
preprocess.sh: line 33: --ligand: command not found
preprocess.sh: line 34: --output_dir: command not found
preprocess.sh: line 35: --name: command not found
Error in custom_input.py for 6v16-QMG
Processing: 
Target directory: .
Output directory: ./output
Step 1: Running custom_input.py...
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/preprocess/custom_input.py", line 5, in <module>
    from preprocess import  gen_graph, to_pyg_graph, get_info, RF_score, GB_score,  analyze_plip_interactions  # 预处理和特征生成相关函数
  File "/xcfhome/zncao02/AffinSculptor/preprocess/preprocess.py", line 9, in <module>
    from ecif import GetECIF  
  File "/xcfhome/zncao02/AffinSculptor/preprocess/ecif.py", line 85, in <module>
    Atom_Keys = pd.read_csv("PDB_Atom_Keys.csv", sep=",")  # PDB 原子名到 ECIF 类型的映射表
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 912, in read_csv
    return _read(filepath_or_buffer, kwds)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 577, in _read
    parser = TextFileReader(filepath_or_buffer, **kwds)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 1407, in __init__
    self._engine = self._make_engine(f, self.engine)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/pandas/io/parsers/readers.py", line 1661, in _make_engine
    self.handles = get_handle(
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/pandas/io/common.py", line 859, in get_handle
    handle = open(
FileNotFoundError: [Errno 2] No such file or directory: 'PDB_Atom_Keys.csv'
preprocess.sh: line 32: --receptor: command not found
preprocess.sh: line 33: --ligand: command not found
preprocess.sh: line 34: --output_dir: command not found
preprocess.sh: line 35: --name: command not found
Error in custom_input.py for 
All processing completed!

# %%
zncao02@f130$ bash preprocess.sh /xcfhome/zncao02/AffinSculptor/data/example.csv
Processing: 6v16-QMG
Target directory: /xcfhome/zncao02/dataset_bap/test_set/custom/6v16-QMG
Output directory: /xcfhome/zncao02/dataset_bap/test_set/custom/6v16-QMG/output
Step 1: Running custom_input.py...
100%|██████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 89.55it/s]
Warning: use "from pymol import cmd" instead of "import cmd"
正在进行PLIP分析: 6v16-QMG
PLIP分析结果类型: <class 'dict'>
发现的结合位点数: 1
lig_ea shape: (58, 4)
pro_ea shape: (212, 4)
lig_sea shape: (0, 4)
pro_sea shape: (0, 4)
lig_pock_ea shape: (18, 4)
Generated PKL file: /xcfhome/zncao02/dataset_bap/test_set/custom/6v16-QMG/output/6v16-QMG_features.pkl
Step 2: Running meshfeatureGen.py...
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/meshfeatureGen.py", line 14, in <module>
    from triangulation.fixmesh import fix_mesh
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/fixmesh.py", line 3, in <module>
    import pymesh
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/pymesh2-0.3-py3.9-linux-x86_64.egg/pymesh/__init__.py", line 18, in <module>
    from .Mesh import Mesh
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/pymesh2-0.3-py3.9-linux-x86_64.egg/pymesh/Mesh.py", line 5, in <module>
    import PyMesh
ImportError: libumfpack.so.5: cannot open shared object file: No such file or directory
Error in meshfeatureGen.py for 6v16-QMG
Processing: 
Target directory: .
Output directory: ./output
Step 1: Running custom_input.py...
  0%|                                                                  | 0/1 [00:00<?, ?it/s]Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/preprocess/custom_input.py", line 185, in <module>
    graph_dicts = Parallel(n_jobs=args.njobs)(  
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/joblib/parallel.py", line 2007, in __call__
    return output if self.return_generator else list(output)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/joblib/parallel.py", line 1650, in _get_outputs
    yield from self._retrieve()
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/joblib/parallel.py", line 1754, in _retrieve
    self._raise_error_fast()
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/joblib/parallel.py", line 1789, in _raise_error_fast
    error_job.get_result(self.timeout)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/joblib/parallel.py", line 745, in get_result
    return self._return_or_raise()
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/joblib/parallel.py", line 763, in _return_or_raise
    raise self._result
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/joblib/parallel.py", line 1469, in dispatch_one_batch
    islice = list(itertools.islice(iterator, big_batch_size))
  File "/xcfhome/zncao02/AffinSculptor/preprocess/custom_input.py", line 186, in <genexpr>
    delayed(parallel_helper)(Path(rec), Path(lig), name, pk, rmsd,  
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/pathlib.py", line 1082, in __new__
    self = cls._from_parts(args, init=False)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/pathlib.py", line 707, in _from_parts
    drv, root, parts = self._parse_args(args)
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/pathlib.py", line 691, in _parse_args
    a = os.fspath(a)
TypeError: expected str, bytes or os.PathLike object, not float
  0%|                                                                  | 0/1 [00:00<?, ?it/s]
Error in custom_input.py for 
All processing completed!

# %%
zncao02@f130$ bash preprocess.sh /xcfhome/zncao02/AffinSculptor/data/example.csv
Processing: 6v16-QMG
Target directory: /xcfhome/zncao02/dataset_bap/test_set/custom/6v16-QMG
Output directory: /xcfhome/zncao02/dataset_bap/test_set/custom/6v16-QMG/output
Step 1: Running custom_input.py...
100%|███████████████████████████████████████████| 1/1 [00:00<00:00, 87.90it/s]
Warning: use "from pymol import cmd" instead of "import cmd"
正在进行PLIP分析: 6v16-QMG
PLIP分析结果类型: <class 'dict'>
发现的结合位点数: 1
lig_ea shape: (58, 4)
pro_ea shape: (212, 4)
lig_sea shape: (0, 4)
pro_sea shape: (0, 4)
lig_pock_ea shape: (18, 4)
Generated PKL file: /xcfhome/zncao02/dataset_bap/test_set/custom/6v16-QMG/output/6v16-QMG_features.pkl
Step 2: Running meshfeatureGen.py...
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/meshfeatureGen.py", line 14, in <module>
    from triangulation.fixmesh import fix_mesh
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/fixmesh.py", line 3, in <module>
    import pymesh
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/pymesh2-0.3-py3.9-linux-x86_64.egg/pymesh/__init__.py", line 18, in <module>
    from .Mesh import Mesh
  File "/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/pymesh2-0.3-py3.9-linux-x86_64.egg/pymesh/Mesh.py", line 5, in <module>
    import PyMesh
ImportError: libumfpack.so.5: cannot open shared object file: No such file or directory
Error in meshfeatureGen.py for 6v16-QMG
All processing completed!

# %%
lig_pock_ea shape: (18, 4)
Generated PKL file: /xcfhome/zncao02/dataset_bap/test_set/custom/6v16-QMG/output/6v16-QMG_features.pkl
Step 2: Running meshfeatureGen.py...
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/prody/utilities/misctools.py:411: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
  import pkg_resources
开始蛋白质-配体表面特征计算...
质子化PDB文件...
提取链 A...
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/meshfeatureGen.py", line 263, in <module>
    result = compute_protein_ligand_surface_features(
  File "/xcfhome/zncao02/AffinSculptor/masif/meshfeatureGen.py", line 61, in compute_protein_ligand_surface_features
    extractPDB(protonated_file, out_filename + ".pdb", chain_id, ligand_code, ligand_chain)
  File "/xcfhome/zncao02/AffinSculptor/masif/source/input_output/extractPDB.py", line 38, in extractPDB
    model = Selection.unfold_entities(struct, "M")[0]
IndexError: list index out of range
Error in meshfeatureGen.py for 6v16-QMG
All processing completed!

# %%
开始蛋白质-配体表面特征计算...
质子化PDB文件...
提取链 A...
计算MSMS分子表面...
处理配体 UNK...
DEBUG: Reading ligand from SDF file: /xcfhome/zncao02/dataset_bap/test_set/custom/6v16-QMG/ligand.sdf
[13:42:14] Explicit valence for atom # 23 N, 4, is greater than permitted
计算化学特征...
  - 计算氢键特征...
  - 计算疏水性特征...
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/meshfeatureGen.py", line 263, in <module>
    result = compute_protein_ligand_surface_features(
  File "/xcfhome/zncao02/AffinSculptor/masif/meshfeatureGen.py", line 114, in compute_protein_ligand_surface_features
    vertex_hphobicity = computeHydrophobicity(names1, ligand_code, rdmol)
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/computeHydrophobicity.py", line 101, in computeHydrophobicity
    hp[ix] = kd_scale[aa]
KeyError: 'UNK'
Error in meshfeatureGen.py for 6v16-QMG

# %%
Step 2: Running meshfeatureGen.py...
/xcfhome/zncao02/anaconda3/envs/dynaformer/lib/python3.9/site-packages/prody/utilities/misctools.py:411: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
  import pkg_resources
开始蛋白质-配体表面特征计算...
质子化PDB文件...
提取链 A...
计算MSMS分子表面...
处理配体 UNK...
DEBUG: Reading ligand from SDF file: /xcfhome/zncao02/dataset_bap/test_set/custom/6v16-QMG/ligand.sdf
[14:12:16] Explicit valence for atom # 23 N, 4, is greater than permitted
计算化学特征...
  - 计算氢键特征...
  - 计算疏水性特征...
Traceback (most recent call last):
  File "/xcfhome/zncao02/AffinSculptor/masif/meshfeatureGen.py", line 263, in <module>
    result = compute_protein_ligand_surface_features(
  File "/xcfhome/zncao02/AffinSculptor/masif/meshfeatureGen.py", line 114, in compute_protein_ligand_surface_features
    vertex_hphobicity = computeHydrophobicity(names1, ligand_code, rdmol)
  File "/xcfhome/zncao02/AffinSculptor/masif/source/triangulation/computeHydrophobicity.py", line 101, in computeHydrophobicity
    hp[ix] = kd_scale[aa]
KeyError: 'UNK'
Error in meshfeatureGen.py for 6v16-QMG
All processing completed!
